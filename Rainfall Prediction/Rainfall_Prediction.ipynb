# %%
# KNN regression applied in Bangladesh rainfall data

import pandas as pd
import numpy as np

#importing the dataset
dataset = pd.read_csv('data/rainfall_bd_2.csv')

#dataset=dataset.fillna(0)

#dataset['Month_Total']=dataset.iloc[:,5:].sum(axis=1)

#result of independentvariable
X = dataset.iloc[:,0:5].values # considering all station name

#result of dependent variable
y = dataset.iloc[:,36].values

#taking careof missing data
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()
X[:,0]= labelencoder_X.fit_transform(X[:,0])
print("\n",X,"\n")

#y=y.astype(int)

X = np.array(X)
y = np.array(y)

from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.20,random_state = 33)


from sklearn.neighbors import KNeighborsRegressor
neigh = KNeighborsRegressor(n_neighbors=5)
neigh.fit(X_train,y_train)

predicted1 = neigh.predict(X_test)
print("Prediction Result: ",predicted1)

print('R-squared test score: {:.3f}'.format(neigh.score(X_test,y_test))) # R-Squared test score

import matplotlib.pyplot as plt
plt.plot(y_test,label='Actual')
plt.plot(predicted1,label='Predicted')
plt.legend()
plt.show()
# Out:
#  [[0 1995 1 24.9 10.7]
#  [0 1995 2 27.7 15.0]
#  [0 1995 3 33.0 19.5]
#  ...,
#  [31 2012 10 31.6 24.3]
#  [31 2012 11 30.6 18.3]
#  [31 2012 12 27.7 16.4]]
#
# Prediction Result:  [ 102.6  739.4  502.6 ...,    4.2    4.   424.4]
# R-squared test score: 0.706

# %%
# Rainfall: 6.1
# Feature Scaling
# KNN

import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsRegressor

#importing the dataset
dataset = pd.read_csv('data/rainfall_bd_2.csv')

#result of independentvariable
X = dataset.iloc[:,0:5].values # considering all station name

#result of dependent variable
y = dataset.iloc[:,36].values

#taking careof missing data
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()
X[:,0]= labelencoder_X.fit_transform(X[:,0])
print("\n",X,"\n")

# Feature Scaling- MinMaxScaler
from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y)

X = np.array(X)
y = np.array(y)

from sklearn.cross_validation import train_test_split

for i in range(1,100):
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.20,random_state = i)

    neigh = KNeighborsRegressor(n_neighbors=8)
    neigh.fit(X_train,y_train)

    predicted1 = neigh.predict(X_test)
    #print("Prediction Result: ",predicted1)
    print("i = ",i)
    print('R-squared test score: {:.3f}'.format(neigh.score(X_test,y_test))) # R-Squared test score

import matplotlib.pyplot as plt
plt.plot(y_test,label='Actual')
plt.plot(predicted1,label='Predicted')
plt.legend()
plt.xlabel('Test Size')
plt.ylabel('Rainfall (mm)')
plt.title('Rainfall Prediction with KNN Regression')
plt.show()
# Out:
#  [[0 1995 1 24.9 10.7]
#  [0 1995 2 27.7 15.0]
#  [0 1995 3 33.0 19.5]
#  ...,
#  [31 2012 10 31.6 24.3]
#  [31 2012 11 30.6 18.3]
#  [31 2012 12 27.7 16.4]]
#
# i =  1
# R-squared test score: 0.666
# C:\Users\TanvirMahmud\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\TanvirMahmud\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\TanvirMahmud\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:324: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# C:\Users\TanvirMahmud\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:359: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# i =  2
# R-squared test score: 0.714
# i =  3
# R-squared test score: 0.688
# i =  4
# R-squared test score: 0.711
# i =  5
# R-squared test score: 0.737
# i =  6
# R-squared test score: 0.692
# i =  7
# R-squared test score: 0.682
# i =  8
# R-squared test score: 0.712
# i =  9
# R-squared test score: 0.732
# i =  10
# R-squared test score: 0.726
# i =  11
# R-squared test score: 0.721
# i =  12
# R-squared test score: 0.683
# i =  13
# R-squared test score: 0.721
# i =  14
# R-squared test score: 0.696
# i =  15
# R-squared test score: 0.696
# i =  16
# R-squared test score: 0.696
# i =  17
# R-squared test score: 0.698
# i =  18
# R-squared test score: 0.716
# i =  19
# R-squared test score: 0.719
# i =  20
# R-squared test score: 0.714
# i =  21
# R-squared test score: 0.732
# i =  22
# R-squared test score: 0.687
# i =  23
# R-squared test score: 0.729
# i =  24
# R-squared test score: 0.735
# i =  25
# R-squared test score: 0.720
# i =  26
# R-squared test score: 0.713
# i =  27
# R-squared test score: 0.710
# i =  28
# R-squared test score: 0.680
# i =  29
# R-squared test score: 0.728
# i =  30
# R-squared test score: 0.718
# i =  31
# R-squared test score: 0.724
# i =  32
# R-squared test score: 0.725
# i =  33
# R-squared test score: 0.718
# i =  34
# R-squared test score: 0.729
# i =  35
# R-squared test score: 0.734
# i =  36
# R-squared test score: 0.739
# i =  37
# R-squared test score: 0.711
# i =  38
# R-squared test score: 0.717
# i =  39
# R-squared test score: 0.745
# i =  40
# R-squared test score: 0.731
# i =  41
# R-squared test score: 0.707
# i =  42
# R-squared test score: 0.738
# i =  43
# R-squared test score: 0.682
# i =  44
# R-squared test score: 0.733
# i =  45
# R-squared test score: 0.668
# i =  46
# R-squared test score: 0.743
# i =  47
# R-squared test score: 0.751
# i =  48
# R-squared test score: 0.740
# i =  49
# R-squared test score: 0.723
# i =  50
# R-squared test score: 0.748
# i =  51
# R-squared test score: 0.734
# i =  52
# R-squared test score: 0.722
# i =  53
# R-squared test score: 0.737
# i =  54
# R-squared test score: 0.733
# i =  55
# R-squared test score: 0.709
# i =  56
# R-squared test score: 0.730
# i =  57
# R-squared test score: 0.722
# i =  58
# R-squared test score: 0.726
# i =  59
# R-squared test score: 0.738
# i =  60
# R-squared test score: 0.725
# i =  61
# R-squared test score: 0.675
# i =  62
# R-squared test score: 0.681
# i =  63
# R-squared test score: 0.719
# i =  64
# R-squared test score: 0.747
# i =  65
# R-squared test score: 0.723
# i =  66
# R-squared test score: 0.742
# i =  67
# R-squared test score: 0.728
# i =  68
# R-squared test score: 0.732
# i =  69
# R-squared test score: 0.707
# i =  70
# R-squared test score: 0.705
# i =  71
# R-squared test score: 0.699
# i =  72
# R-squared test score: 0.748
# i =  73
# R-squared test score: 0.710
# i =  74
# R-squared test score: 0.698
# i =  75
# R-squared test score: 0.698
# i =  76
# R-squared test score: 0.684
# i =  77
# R-squared test score: 0.722
# i =  78
# R-squared test score: 0.741
# i =  79
# R-squared test score: 0.723
# i =  80
# R-squared test score: 0.723
# i =  81
# R-squared test score: 0.735
# i =  82
# R-squared test score: 0.702
# i =  83
# R-squared test score: 0.697
# i =  84
# R-squared test score: 0.737
# i =  85
# R-squared test score: 0.722
# i =  86
# R-squared test score: 0.704
# i =  87
# R-squared test score: 0.729
# i =  88
# R-squared test score: 0.713
# i =  89
# R-squared test score: 0.711
# i =  90
# R-squared test score: 0.728
# i =  91
# R-squared test score: 0.696
# i =  92
# R-squared test score: 0.719
# i =  93
# R-squared test score: 0.689
# i =  94
# R-squared test score: 0.720
# i =  95
# R-squared test score: 0.717
# i =  96
# R-squared test score: 0.746
# i =  97
# R-squared test score: 0.678
# i =  98
# R-squared test score: 0.726
# i =  99
# R-squared test score: 0.733

# %%
# 7.1
# Random Forest Regression

import pandas as pd
import numpy as np

#importing the dataset
dataset = pd.read_csv('data/rainfall_bd_2.csv')

#result of independentvariable
X = dataset.iloc[:,0:5].values # considering all station name

#result of dependent variable
y = dataset.iloc[:,36].values

#taking careof missing data
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()
X[:,0]= labelencoder_X.fit_transform(X[:,0])
print("\n",X,"\n")

# Feature Scaling- MinMaxScaler
from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y)

X = np.array(X)
y = np.array(y)

from sklearn.cross_validation import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.20,random_state = 33)


from sklearn.ensemble import RandomForestRegressor

#regressor = RandomForestRegressor(random_state=0, n_estimators=200, max_depth=None, max_features=1, min_samples_leaf=1, min_samples_split=2, bootstrap=False)

for i in range(1,100):
    #regressor = RandomForestRegressor(max_depth=None, random_state=i)
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.20,random_state = i)
    regressor = RandomForestRegressor(n_estimators=200, max_depth=None, max_features=1, min_samples_leaf=1, min_samples_split=2, bootstrap=False)
    regressor.fit(X_train, y_train)

    predicted1 = regressor.predict(X_test)
    #print("Prediction Result: ",predicted1)
    print("i = ",i)

    print('R-squared test score: {:.3f}'.format(regressor.score(X_test,y_test))) # R-Squared test score

import matplotlib.pyplot as plt
plt.plot(y_test,label='Actual')
plt.plot(predicted1,label='Predicted')
plt.legend()
plt.xlabel('Test Size')
plt.ylabel('Rainfall (mm)')
plt.title('Rainfall Prediction with Random Forest Regression')
plt.show()
# Out:
#  [[0 1995 1 24.9 10.7]
#  [0 1995 2 27.7 15.0]
#  [0 1995 3 33.0 19.5]
#  ...,
#  [31 2012 10 31.6 24.3]
#  [31 2012 11 30.6 18.3]
#  [31 2012 12 27.7 16.4]]
# C:\Users\TanvirMahmud\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\TanvirMahmud\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\TanvirMahmud\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:324: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# C:\Users\TanvirMahmud\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:359: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# i =  1
# R-squared test score: 0.739
# i =  2
# R-squared test score: 0.782
# i =  3
# R-squared test score: 0.758
# i =  4
# R-squared test score: 0.785
# i =  5
# R-squared test score: 0.814
# i =  6
# R-squared test score: 0.743
# i =  7
# R-squared test score: 0.758
# i =  8
# R-squared test score: 0.768
# i =  9
# R-squared test score: 0.789
# i =  10
# R-squared test score: 0.795
# i =  11
# R-squared test score: 0.792
# i =  12
# R-squared test score: 0.746
# i =  13
# R-squared test score: 0.792
# i =  14
# R-squared test score: 0.755
# i =  15
# R-squared test score: 0.729
# i =  16
# R-squared test score: 0.757
# i =  17
# R-squared test score: 0.784
# i =  18
# R-squared test score: 0.779
# i =  19
# R-squared test score: 0.780
# i =  20
# R-squared test score: 0.784
# i =  21
# R-squared test score: 0.785
# i =  22
# R-squared test score: 0.748
# i =  23
# R-squared test score: 0.802
# i =  24
# R-squared test score: 0.803
# i =  25
# R-squared test score: 0.800
# i =  26
# R-squared test score: 0.781
# i =  27
# R-squared test score: 0.765
# i =  28
# R-squared test score: 0.729
# i =  29
# R-squared test score: 0.805
# i =  30
# R-squared test score: 0.758
# i =  31
# R-squared test score: 0.812
# i =  32
# R-squared test score: 0.809
# i =  33
# R-squared test score: 0.790
# i =  34
# R-squared test score: 0.791
# i =  35
# R-squared test score: 0.804
# i =  36
# R-squared test score: 0.805
# i =  37
# R-squared test score: 0.798
# i =  38
# R-squared test score: 0.801
# i =  39
# R-squared test score: 0.813
# i =  40
# R-squared test score: 0.802
# i =  41
# R-squared test score: 0.773
# i =  42
# R-squared test score: 0.808
# i =  43
# R-squared test score: 0.762
# i =  44
# R-squared test score: 0.790
# i =  45
# R-squared test score: 0.718
# i =  46
# R-squared test score: 0.797
# i =  47
# R-squared test score: 0.832
# i =  48
# R-squared test score: 0.805
# i =  49
# R-squared test score: 0.788
# i =  50
# R-squared test score: 0.811
# i =  51
# R-squared test score: 0.794
# i =  52
# R-squared test score: 0.793
# i =  53
# R-squared test score: 0.808
# i =  54
# R-squared test score: 0.792
# i =  55
# R-squared test score: 0.779
# i =  56
# R-squared test score: 0.792
# i =  57
# R-squared test score: 0.805
# i =  58
# R-squared test score: 0.801
# i =  59
# R-squared test score: 0.800
# i =  60
# R-squared test score: 0.773
# i =  61
# R-squared test score: 0.732
# i =  62
# R-squared test score: 0.747
# i =  63
# R-squared test score: 0.790
# i =  64
# R-squared test score: 0.808
# i =  65
# R-squared test score: 0.789
# i =  66
# R-squared test score: 0.797
# i =  67
# R-squared test score: 0.796
# i =  68
# R-squared test score: 0.814
# i =  69
# R-squared test score: 0.788
# i =  70
# R-squared test score: 0.762
# i =  71
# R-squared test score: 0.735
# i =  72
# R-squared test score: 0.805
# i =  73
# R-squared test score: 0.795
# i =  74
# R-squared test score: 0.776
# i =  75
# R-squared test score: 0.770
# i =  76
# R-squared test score: 0.751
# i =  77
# R-squared test score: 0.791
# i =  78
# R-squared test score: 0.811
# i =  79
# R-squared test score: 0.805
# i =  80
# R-squared test score: 0.795
# i =  81
# R-squared test score: 0.797
# i =  82
# R-squared test score: 0.775
# i =  83
# R-squared test score: 0.768
# i =  84
# R-squared test score: 0.810
# i =  85
# R-squared test score: 0.804
# i =  86
# R-squared test score: 0.791
# i =  87
# R-squared test score: 0.788
# i =  88
# R-squared test score: 0.783
# i =  89
# R-squared test score: 0.791
# i =  90
# R-squared test score: 0.788
# i =  91
# R-squared test score: 0.753
# i =  92
# R-squared test score: 0.778
# i =  93
# R-squared test score: 0.731
# i =  94
# R-squared test score: 0.781
# i =  95
# R-squared test score: 0.810
# i =  96
# R-squared test score: 0.806
# i =  97
# R-squared test score: 0.750
# i =  98
# R-squared test score: 0.808
# i =  99
# R-squared test score: 0.804

# %%
# Rainfall: 8.1
# Decision Tree Regressor

import pandas as pd
import numpy as np

#importing the dataset
dataset = pd.read_csv('data/rainfall_bd_2.csv')

#result of independentvariable
X = dataset.iloc[:,0:5].values # considering all station name

#result of dependent variable
y = dataset.iloc[:,36].values

#taking careof missing data
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()
X[:,0]= labelencoder_X.fit_transform(X[:,0])
print("\n",X,"\n")

# Feature Scaling- MinMaxScaler
from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y)

X = np.array(X)
y = np.array(y)

from sklearn.cross_validation import train_test_split

from sklearn.tree import DecisionTreeRegressor
for i in range(1,100):
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.20,random_state = i)
    regressor = DecisionTreeRegressor(max_depth=6)
    regressor.fit(X_train,y_train)

    predicted1 = regressor.predict(X_test)
    #print("Prediction Result: ",predicted1)
    print('i =',i)
    print('R-squared test score: {:.3f}'.format(regressor.score(X_test,y_test))) # R-Squared test score

import matplotlib.pyplot as plt
plt.plot(y_test,label='Actual')
plt.plot(predicted1,label='Predicted')
plt.legend()
plt.xlabel('Test Size')
plt.ylabel('Rainfall (mm)')
plt.title('Rainfall Prediction with Decision Tree Regression')
plt.show()
# Out:
#  [[0 1995 1 24.9 10.7]
#  [0 1995 2 27.7 15.0]
#  [0 1995 3 33.0 19.5]
#  ...,
#  [31 2012 10 31.6 24.3]
#  [31 2012 11 30.6 18.3]
#  [31 2012 12 27.7 16.4]]
#
# i = 1
# R-squared test score: 0.678
# i = 2
# R-squared test score: 0.731
# i = 3
# R-squared test score: 0.688
# i = 4
# R-squared test score: 0.741
# i = 5
# R-squared test score: 0.763
# i = 6
# R-squared test score: 0.692
# C:\Users\TanvirMahmud\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\TanvirMahmud\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\TanvirMahmud\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:324: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# C:\Users\TanvirMahmud\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:359: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# i = 7
# R-squared test score: 0.693
# i = 8
# R-squared test score: 0.707
# i = 9
# R-squared test score: 0.740
# i = 10
# R-squared test score: 0.722
# i = 11
# R-squared test score: 0.732
# i = 12
# R-squared test score: 0.695
# i = 13
# R-squared test score: 0.726
# i = 14
# R-squared test score: 0.684
# i = 15
# R-squared test score: 0.656
# i = 16
# R-squared test score: 0.703
# i = 17
# R-squared test score: 0.719
# i = 18
# R-squared test score: 0.723
# i = 19
# R-squared test score: 0.689
# i = 20
# R-squared test score: 0.706
# i = 21
# R-squared test score: 0.717
# i = 22
# R-squared test score: 0.669
# i = 23
# R-squared test score: 0.757
# i = 24
# R-squared test score: 0.762
# i = 25
# R-squared test score: 0.746
# i = 26
# R-squared test score: 0.725
# i = 27
# R-squared test score: 0.686
# i = 28
# R-squared test score: 0.679
# i = 29
# R-squared test score: 0.749
# i = 30
# R-squared test score: 0.692
# i = 31
# R-squared test score: 0.780
# i = 32
# R-squared test score: 0.758
# i = 33
# R-squared test score: 0.730
# i = 34
# R-squared test score: 0.731
# i = 35
# R-squared test score: 0.738
# i = 36
# R-squared test score: 0.753
# i = 37
# R-squared test score: 0.737
# i = 38
# R-squared test score: 0.727
# i = 39
# R-squared test score: 0.749
# i = 40
# R-squared test score: 0.749
# i = 41
# R-squared test score: 0.699
# i = 42
# R-squared test score: 0.738
# i = 43
# R-squared test score: 0.684
# i = 44
# R-squared test score: 0.734
# i = 45
# R-squared test score: 0.661
# i = 46
# R-squared test score: 0.730
# i = 47
# R-squared test score: 0.763
# i = 48
# R-squared test score: 0.754
# i = 49
# R-squared test score: 0.740
# i = 50
# R-squared test score: 0.738
# i = 51
# R-squared test score: 0.736
# i = 52
# R-squared test score: 0.737
# i = 53
# R-squared test score: 0.754
# i = 54
# R-squared test score: 0.746
# i = 55
# R-squared test score: 0.712
# i = 56
# R-squared test score: 0.731
# i = 57
# R-squared test score: 0.752
# i = 58
# R-squared test score: 0.740
# i = 59
# R-squared test score: 0.721
# i = 60
# R-squared test score: 0.734
# i = 61
# R-squared test score: 0.683
# i = 62
# R-squared test score: 0.680
# i = 63
# R-squared test score: 0.738
# i = 64
# R-squared test score: 0.752
# i = 65
# R-squared test score: 0.740
# i = 66
# R-squared test score: 0.728
# i = 67
# R-squared test score: 0.727
# i = 68
# R-squared test score: 0.759
# i = 69
# R-squared test score: 0.729
# i = 70
# R-squared test score: 0.696
# i = 71
# R-squared test score: 0.680
# i = 72
# R-squared test score: 0.729
# i = 73
# R-squared test score: 0.711
# i = 74
# R-squared test score: 0.732
# i = 75
# R-squared test score: 0.688
# i = 76
# R-squared test score: 0.691
# i = 77
# R-squared test score: 0.723
# i = 78
# R-squared test score: 0.748
# i = 79
# R-squared test score: 0.741
# i = 80
# R-squared test score: 0.733
# i = 81
# R-squared test score: 0.746
# i = 82
# R-squared test score: 0.714
# i = 83
# R-squared test score: 0.697
# i = 84
# R-squared test score: 0.734
# i = 85
# R-squared test score: 0.741
# i = 86
# R-squared test score: 0.731
# i = 87
# R-squared test score: 0.733
# i = 88
# R-squared test score: 0.716
# i = 89
# R-squared test score: 0.736
# i = 90
# R-squared test score: 0.718
# i = 91
# R-squared test score: 0.680
# i = 92
# R-squared test score: 0.721
# i = 93
# R-squared test score: 0.695
# i = 94
# R-squared test score: 0.734
# i = 95
# R-squared test score: 0.741
# i = 96
# R-squared test score: 0.720
# i = 97
# R-squared test score: 0.682
# i = 98
# R-squared test score: 0.749
# i = 99
# R-squared test score: 0.734
