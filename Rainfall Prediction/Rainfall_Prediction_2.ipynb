# %%
# KNN regression - 1 
# applied in Bangladesh rainfall data

import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsRegressor
import warnings; warnings.simplefilter('ignore') # Jupyter notebook warning message remove

#importing the dataset
dataset = pd.read_csv('data/rainfall_bd_2.csv')

#dataset=dataset.fillna(0)

#dataset['Month_Total']=dataset.iloc[:,5:].sum(axis=1)

#result of independentvariable
X = dataset.iloc[:,0:5].values # considering all station name

#result of dependent variable
y = dataset.iloc[:,36].values

#taking careof categorical data
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()
X[:,0]= labelencoder_X.fit_transform(X[:,0])
print("\n",X,"\n")

#y=y.astype(int)

X = np.array(X)
y = np.array(y)

from sklearn.cross_validation import train_test_split

for i in range(1,100):
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.20,random_state = i)
    
    neigh = KNeighborsRegressor(n_neighbors=8)
    neigh.fit(X_train,y_train)

    predicted = neigh.predict(X_test)
    #print("Prediction Result: ",predicted)
    print("i = ",i)
    print('R-squared test score: {:.3f}'.format(neigh.score(X_test,y_test))) # R-Squared test score

import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
plt.plot(y_test[0:50],label="Actual")
plt.plot(predicted[0:50],color="indianred",label="Predicted")
plt.xlabel('Number of Observation')
plt.ylabel('Rainfall (mm)')
plt.title('Rainfall Prediction with KNN Regression',fontsize=10)
plt.legend()
plt.show()
# Out:
#  [[0 1995 1 24.9 10.7]
#  [0 1995 2 27.7 15.0]
#  [0 1995 3 33.0 19.5]
#  ...,
#  [31 2012 10 31.6 24.3]
#  [31 2012 11 30.6 18.3]
#  [31 2012 12 27.7 16.4]]
#
# i =  1
# R-squared test score: 0.660
# i =  2
# R-squared test score: 0.711
# i =  3
# R-squared test score: 0.686
# i =  4
# R-squared test score: 0.709
# i =  5
# R-squared test score: 0.722
# i =  6
# R-squared test score: 0.669
# i =  7
# R-squared test score: 0.666
# i =  8
# R-squared test score: 0.688
# i =  9
# R-squared test score: 0.713
# i =  10
# R-squared test score: 0.701
# i =  11
# R-squared test score: 0.722
# i =  12
# R-squared test score: 0.658
# i =  13
# R-squared test score: 0.699
# i =  14
# R-squared test score: 0.673
# i =  15
# R-squared test score: 0.671
# i =  16
# R-squared test score: 0.684
# i =  17
# R-squared test score: 0.676
# i =  18
# R-squared test score: 0.701
# i =  19
# R-squared test score: 0.692
# i =  20
# R-squared test score: 0.692
# i =  21
# R-squared test score: 0.724
# i =  22
# R-squared test score: 0.679
# i =  23
# R-squared test score: 0.720
# i =  24
# R-squared test score: 0.730
# i =  25
# R-squared test score: 0.722
# i =  26
# R-squared test score: 0.699
# i =  27
# R-squared test score: 0.697
# i =  28
# R-squared test score: 0.661
# i =  29
# R-squared test score: 0.734
# i =  30
# R-squared test score: 0.694
# i =  31
# R-squared test score: 0.716
# i =  32
# R-squared test score: 0.704
# i =  33
# R-squared test score: 0.704
# i =  34
# R-squared test score: 0.726
# i =  35
# R-squared test score: 0.717
# i =  36
# R-squared test score: 0.724
# i =  37
# R-squared test score: 0.695
# i =  38
# R-squared test score: 0.703
# i =  39
# R-squared test score: 0.720
# i =  40
# R-squared test score: 0.718
# i =  41
# R-squared test score: 0.673
# i =  42
# R-squared test score: 0.717
# i =  43
# R-squared test score: 0.677
# i =  44
# R-squared test score: 0.717
# i =  45
# R-squared test score: 0.650
# i =  46
# R-squared test score: 0.722
# i =  47
# R-squared test score: 0.731
# i =  48
# R-squared test score: 0.717
# i =  49
# R-squared test score: 0.711
# i =  50
# R-squared test score: 0.738
# i =  51
# R-squared test score: 0.718
# i =  52
# R-squared test score: 0.714
# i =  53
# R-squared test score: 0.718
# i =  54
# R-squared test score: 0.720
# i =  55
# R-squared test score: 0.692
# i =  56
# R-squared test score: 0.715
# i =  57
# R-squared test score: 0.700
# i =  58
# R-squared test score: 0.700
# i =  59
# R-squared test score: 0.730
# i =  60
# R-squared test score: 0.698
# i =  61
# R-squared test score: 0.666
# i =  62
# R-squared test score: 0.666
# i =  63
# R-squared test score: 0.716
# i =  64
# R-squared test score: 0.723
# i =  65
# R-squared test score: 0.698
# i =  66
# R-squared test score: 0.705
# i =  67
# R-squared test score: 0.707
# i =  68
# R-squared test score: 0.712
# i =  69
# R-squared test score: 0.697
# i =  70
# R-squared test score: 0.691
# i =  71
# R-squared test score: 0.693
# i =  72
# R-squared test score: 0.729
# i =  73
# R-squared test score: 0.710
# i =  74
# R-squared test score: 0.690
# i =  75
# R-squared test score: 0.693
# i =  76
# R-squared test score: 0.679
# i =  77
# R-squared test score: 0.699
# i =  78
# R-squared test score: 0.721
# i =  79
# R-squared test score: 0.732
# i =  80
# R-squared test score: 0.704
# i =  81
# R-squared test score: 0.730
# i =  82
# R-squared test score: 0.692
# i =  83
# R-squared test score: 0.697
# i =  84
# R-squared test score: 0.718
# i =  85
# R-squared test score: 0.685
# i =  86
# R-squared test score: 0.680
# i =  87
# R-squared test score: 0.712
# i =  88
# R-squared test score: 0.712
# i =  89
# R-squared test score: 0.705
# i =  90
# R-squared test score: 0.722
# i =  91
# R-squared test score: 0.666
# i =  92
# R-squared test score: 0.709
# i =  93
# R-squared test score: 0.683
# i =  94
# R-squared test score: 0.708
# i =  95
# R-squared test score: 0.713
# i =  96
# R-squared test score: 0.720
# i =  97
# R-squared test score: 0.667
# i =  98
# R-squared test score: 0.721
# i =  99
# R-squared test score: 0.718

# %%
# Rainfall: 6.1
# KNN regression - 2
# with Feature Scaling

import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsRegressor
import warnings; warnings.simplefilter('ignore') # Jupyter notebook warning message remove

#importing the dataset
dataset = pd.read_csv('data/rainfall_bd_2.csv')

#result of independentvariable
X = dataset.iloc[:,0:5].values # considering all station name

#result of dependent variable
y = dataset.iloc[:,36].values

#taking careof missing data
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()
X[:,0]= labelencoder_X.fit_transform(X[:,0])
print("\n",X,"\n")

# Feature Scaling- MinMaxScaler
from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler()

X = np.array(X)
y = np.array(y)

from sklearn.cross_validation import train_test_split

for i in range(1,100):
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.20,random_state = i)

    # Feature Scaling- MinMaxScaler
    
    X_train_n = scaler.fit_transform(X_train) # X_train_n = normalized
    X_test_n = scaler.fit_transform(X_test)
    y_train_n = scaler.fit_transform(y_train)
    y_test_n = scaler.fit_transform(y_test)
    
    neigh = KNeighborsRegressor(n_neighbors=8)
    neigh.fit(X_train_n,y_train_n)

    predicted = neigh.predict(X_test_n)
    #print("Prediction Result: ",predicted)
    print("i = ",i)
    print('R-squared test score: {:.3f}'.format(neigh.score(X_test_n,y_test_n))) # R-Squared test score


#Undo the scaling of X according to feature_range.    
X_train_d = scaler.inverse_transform(X_train_n) # X_train_d = dnormalized
X_test_d = scaler.inverse_transform(X_test_n)
y_train_d = scaler.inverse_transform(y_train_n)
y_test_d = scaler.inverse_transform(y_test_n)
predicted_d = scaler.inverse_transform(predicted)    
    
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
plt.plot(y_test_d[0:50],label="Actual")
plt.plot(predicted_d[0:50],color="indianred",label="Predicted")
plt.xlabel('Number of Observation')
plt.ylabel('Rainfall (mm)')
plt.title('Rainfall Prediction with KNN Regression using Feature Scaling',fontsize=10)
plt.legend()
plt.show()
# Out:
#  [[0 1995 1 24.9 10.7]
#  [0 1995 2 27.7 15.0]
#  [0 1995 3 33.0 19.5]
#  ...,
#  [31 2012 10 31.6 24.3]
#  [31 2012 11 30.6 18.3]
#  [31 2012 12 27.7 16.4]]
#
# i =  1
# R-squared test score: 0.329
# i =  2
# R-squared test score: 0.394
# i =  3
# R-squared test score: 0.492
# i =  4
# R-squared test score: 0.513
# i =  5
# R-squared test score: 0.388
# i =  6
# R-squared test score: 0.468
# i =  7
# R-squared test score: 0.547
# i =  8
# R-squared test score: 0.514
# i =  9
# R-squared test score: 0.471
# i =  10
# R-squared test score: 0.470
# i =  11
# R-squared test score: 0.484
# i =  12
# R-squared test score: 0.613
# i =  13
# R-squared test score: 0.473
# i =  14
# R-squared test score: 0.668
# i =  15
# R-squared test score: 0.011
# i =  16
# R-squared test score: 0.347
# i =  17
# R-squared test score: 0.500
# i =  18
# R-squared test score: 0.450
# i =  19
# R-squared test score: 0.575
# i =  20
# R-squared test score: 0.544
# i =  21
# R-squared test score: 0.449
# i =  22
# R-squared test score: 0.585
# i =  23
# R-squared test score: 0.487
# i =  24
# R-squared test score: 0.477
# i =  25
# R-squared test score: 0.623
# i =  26
# R-squared test score: 0.529
# i =  27
# R-squared test score: 0.302
# i =  28
# R-squared test score: 0.234
# i =  29
# R-squared test score: 0.382
# i =  30
# R-squared test score: 0.464
# i =  31
# R-squared test score: 0.550
# i =  32
# R-squared test score: 0.460
# i =  33
# R-squared test score: 0.480
# i =  34
# R-squared test score: 0.526
# i =  35
# R-squared test score: 0.488
# i =  36
# R-squared test score: 0.473
# i =  37
# R-squared test score: 0.378
# i =  38
# R-squared test score: 0.501
# i =  39
# R-squared test score: 0.551
# i =  40
# R-squared test score: 0.526
# i =  41
# R-squared test score: 0.546
# i =  42
# R-squared test score: 0.398
# i =  43
# R-squared test score: 0.633
# i =  44
# R-squared test score: 0.319
# i =  45
# R-squared test score: 0.517
# i =  46
# R-squared test score: 0.465
# i =  47
# R-squared test score: 0.481
# i =  48
# R-squared test score: 0.541
# i =  49
# R-squared test score: 0.446
# i =  50
# R-squared test score: 0.311
# i =  51
# R-squared test score: 0.353
# i =  52
# R-squared test score: 0.360
# i =  53
# R-squared test score: 0.489
# i =  54
# R-squared test score: 0.379
# i =  55
# R-squared test score: 0.453
# i =  56
# R-squared test score: 0.490
# i =  57
# R-squared test score: 0.405
# i =  58
# R-squared test score: 0.366
# i =  59
# R-squared test score: 0.426
# i =  60
# R-squared test score: 0.468
# i =  61
# R-squared test score: 0.655
# i =  62
# R-squared test score: 0.481
# i =  63
# R-squared test score: 0.455
# i =  64
# R-squared test score: 0.619
# i =  65
# R-squared test score: 0.498
# i =  66
# R-squared test score: 0.442
# i =  67
# R-squared test score: 0.541
# i =  68
# R-squared test score: 0.394
# i =  69
# R-squared test score: 0.407
# i =  70
# R-squared test score: 0.343
# i =  71
# R-squared test score: 0.575
# i =  72
# R-squared test score: 0.440
# i =  73
# R-squared test score: 0.451
# i =  74
# R-squared test score: 0.616
# i =  75
# R-squared test score: 0.453
# i =  76
# R-squared test score: 0.410
# i =  77
# R-squared test score: 0.340
# i =  78
# R-squared test score: 0.414
# i =  79
# R-squared test score: 0.313
# i =  80
# R-squared test score: 0.598
# i =  81
# R-squared test score: 0.576
# i =  82
# R-squared test score: 0.534
# i =  83
# R-squared test score: 0.332
# i =  84
# R-squared test score: 0.350
# i =  85
# R-squared test score: 0.433
# i =  86
# R-squared test score: 0.448
# i =  87
# R-squared test score: 0.355
# i =  88
# R-squared test score: 0.402
# i =  89
# R-squared test score: 0.480
# i =  90
# R-squared test score: 0.288
# i =  91
# R-squared test score: 0.570
# i =  92
# R-squared test score: 0.246
# i =  93
# R-squared test score: 0.609
# i =  94
# R-squared test score: 0.355
# i =  95
# R-squared test score: 0.424
# i =  96
# R-squared test score: 0.374
# i =  97
# R-squared test score: 0.602
# i =  98
# R-squared test score: 0.428
# i =  99
# R-squared test score: 0.523

# %%
# Rainfall: 8.1
# Decision Tree Regression - 1

import pandas as pd
import numpy as np
import warnings; warnings.simplefilter('ignore') # Jupyter notebook warning message remove

#importing the dataset
dataset = pd.read_csv('data/rainfall_bd_2.csv')

#result of independentvariable
X = dataset.iloc[:,0:5].values # considering all station name

#result of dependent variable
y = dataset.iloc[:,36].values

#taking careof missing data
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()
X[:,0]= labelencoder_X.fit_transform(X[:,0])
print("\n",X,"\n")

# Feature Scaling- MinMaxScaler
from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y)

X = np.array(X)
y = np.array(y)

from sklearn.cross_validation import train_test_split

from sklearn.tree import DecisionTreeRegressor
for i in range(1,100):
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.20,random_state = i)
    regressor = DecisionTreeRegressor(max_depth=6)
    regressor.fit(X_train,y_train)

    predicted = regressor.predict(X_test)
    #print("Prediction Result: ",predicted1)
    print('i =',i)
    print('R-squared test score: {:.3f}'.format(regressor.score(X_test,y_test))) # R-Squared test score

import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
plt.plot(y_test[0:50],label="Actual")
plt.plot(predicted[0:50],color="indianred",label="Predicted")
plt.xlabel('Number of Observation')
plt.ylabel('Rainfall (mm)')
plt.title('Rainfall Prediction with Decision Tree Regression',fontsize=10)
plt.legend()
plt.show()
# Out:
#  [[0 1995 1 24.9 10.7]
#  [0 1995 2 27.7 15.0]
#  [0 1995 3 33.0 19.5]
#  ...,
#  [31 2012 10 31.6 24.3]
#  [31 2012 11 30.6 18.3]
#  [31 2012 12 27.7 16.4]]
#
# i = 1
# R-squared test score: 0.678
# i = 2
# R-squared test score: 0.731
# i = 3
# R-squared test score: 0.688
# i = 4
# R-squared test score: 0.741
# i = 5
# R-squared test score: 0.763
# i = 6
# R-squared test score: 0.692
# i = 7
# R-squared test score: 0.693
# i = 8
# R-squared test score: 0.707
# i = 9
# R-squared test score: 0.739
# i = 10
# R-squared test score: 0.722
# i = 11
# R-squared test score: 0.732
# i = 12
# R-squared test score: 0.695
# i = 13
# R-squared test score: 0.726
# i = 14
# R-squared test score: 0.684
# i = 15
# R-squared test score: 0.656
# i = 16
# R-squared test score: 0.703
# i = 17
# R-squared test score: 0.719
# i = 18
# R-squared test score: 0.723
# i = 19
# R-squared test score: 0.689
# i = 20
# R-squared test score: 0.706
# i = 21
# R-squared test score: 0.717
# i = 22
# R-squared test score: 0.669
# i = 23
# R-squared test score: 0.757
# i = 24
# R-squared test score: 0.762
# i = 25
# R-squared test score: 0.746
# i = 26
# R-squared test score: 0.725
# i = 27
# R-squared test score: 0.684
# i = 28
# R-squared test score: 0.679
# i = 29
# R-squared test score: 0.749
# i = 30
# R-squared test score: 0.692
# i = 31
# R-squared test score: 0.780
# i = 32
# R-squared test score: 0.758
# i = 33
# R-squared test score: 0.730
# i = 34
# R-squared test score: 0.731
# i = 35
# R-squared test score: 0.738
# i = 36
# R-squared test score: 0.753
# i = 37
# R-squared test score: 0.733
# i = 38
# R-squared test score: 0.727
# i = 39
# R-squared test score: 0.749
# i = 40
# R-squared test score: 0.749
# i = 41
# R-squared test score: 0.699
# i = 42
# R-squared test score: 0.738
# i = 43
# R-squared test score: 0.684
# i = 44
# R-squared test score: 0.734
# i = 45
# R-squared test score: 0.661
# i = 46
# R-squared test score: 0.730
# i = 47
# R-squared test score: 0.763
# i = 48
# R-squared test score: 0.754
# i = 49
# R-squared test score: 0.740
# i = 50
# R-squared test score: 0.738
# i = 51
# R-squared test score: 0.736
# i = 52
# R-squared test score: 0.737
# i = 53
# R-squared test score: 0.754
# i = 54
# R-squared test score: 0.746
# i = 55
# R-squared test score: 0.712
# i = 56
# R-squared test score: 0.731
# i = 57
# R-squared test score: 0.752
# i = 58
# R-squared test score: 0.740
# i = 59
# R-squared test score: 0.721
# i = 60
# R-squared test score: 0.734
# i = 61
# R-squared test score: 0.683
# i = 62
# R-squared test score: 0.680
# i = 63
# R-squared test score: 0.738
# i = 64
# R-squared test score: 0.752
# i = 65
# R-squared test score: 0.740
# i = 66
# R-squared test score: 0.728
# i = 67
# R-squared test score: 0.727
# i = 68
# R-squared test score: 0.759
# i = 69
# R-squared test score: 0.729
# i = 70
# R-squared test score: 0.696
# i = 71
# R-squared test score: 0.680
# i = 72
# R-squared test score: 0.729
# i = 73
# R-squared test score: 0.711
# i = 74
# R-squared test score: 0.732
# i = 75
# R-squared test score: 0.688
# i = 76
# R-squared test score: 0.691
# i = 77
# R-squared test score: 0.724
# i = 78
# R-squared test score: 0.748
# i = 79
# R-squared test score: 0.741
# i = 80
# R-squared test score: 0.733
# i = 81
# R-squared test score: 0.746
# i = 82
# R-squared test score: 0.714
# i = 83
# R-squared test score: 0.697
# i = 84
# R-squared test score: 0.734
# i = 85
# R-squared test score: 0.741
# i = 86
# R-squared test score: 0.731
# i = 87
# R-squared test score: 0.733
# i = 88
# R-squared test score: 0.716
# i = 89
# R-squared test score: 0.736
# i = 90
# R-squared test score: 0.718
# i = 91
# R-squared test score: 0.680
# i = 92
# R-squared test score: 0.721
# i = 93
# R-squared test score: 0.695
# i = 94
# R-squared test score: 0.734
# i = 95
# R-squared test score: 0.741
# i = 96
# R-squared test score: 0.720
# i = 97
# R-squared test score: 0.682
# i = 98
# R-squared test score: 0.749
# i = 99
# R-squared test score: 0.734

# %%
# Rainfall: 8.1
# Decision Tree Regression - 2
# with Feature Scaling

import pandas as pd
import numpy as np
import warnings; warnings.simplefilter('ignore') # Jupyter notebook warning message remove

#importing the dataset
dataset = pd.read_csv('data/rainfall_bd_2.csv')

#result of independentvariable
X = dataset.iloc[:,0:5].values # considering all station name

#result of dependent variable
y = dataset.iloc[:,36].values

#taking careof missing data
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()
X[:,0]= labelencoder_X.fit_transform(X[:,0])
print("\n",X,"\n")

# Feature Scaling- MinMaxScaler
from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler()

X = np.array(X)
y = np.array(y)

from sklearn.cross_validation import train_test_split

from sklearn.tree import DecisionTreeRegressor
for i in range(1,100):
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.20,random_state = i)
    
    # Feature Scaling- MinMaxScaler
    X_train_n = scaler.fit_transform(X_train) # X_train_n = normalized
    X_test_n = scaler.fit_transform(X_test)
    y_train_n = scaler.fit_transform(y_train)
    y_test_n = scaler.fit_transform(y_test)
    
    regressor = DecisionTreeRegressor(max_depth=6)
    regressor.fit(X_train_n,y_train_n)

    predicted = regressor.predict(X_test_n)
    #print("Prediction Result: ",predicted1)
    print('i =',i)
    print('R-squared test score: {:.3f}'.format(regressor.score(X_test_n,y_test_n))) # R-Squared test score

#Undo the scaling of X according to feature_range.    
X_train_d = scaler.inverse_transform(X_train_n) # X_train_d = dnormalized
X_test_d = scaler.inverse_transform(X_test_n)
y_train_d = scaler.inverse_transform(y_train_n)
y_test_d = scaler.inverse_transform(y_test_n)
predicted_d = scaler.inverse_transform(predicted)
    
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
plt.plot(y_test_d[0:50],label="Actual")
plt.plot(predicted_d[0:50],color="indianred",label="Predicted")
plt.xlabel('Number of Observation')
plt.ylabel('Rainfall (mm)')
plt.title('Rainfall Prediction with Decision Tree Regression using Feature Scaling',fontsize=10)
plt.legend()
plt.show()
# Out:
#  [[0 1995 1 24.9 10.7]
#  [0 1995 2 27.7 15.0]
#  [0 1995 3 33.0 19.5]
#  ...,
#  [31 2012 10 31.6 24.3]
#  [31 2012 11 30.6 18.3]
#  [31 2012 12 27.7 16.4]]
#
# i = 1
# R-squared test score: 0.056
# i = 2
# R-squared test score: 0.369
# i = 3
# R-squared test score: 0.482
# i = 4
# R-squared test score: 0.503
# i = 5
# R-squared test score: 0.371
# i = 6
# R-squared test score: 0.516
# i = 7
# R-squared test score: 0.531
# i = 8
# R-squared test score: 0.563
# i = 9
# R-squared test score: 0.492
# i = 10
# R-squared test score: 0.498
# i = 11
# R-squared test score: 0.522
# i = 12
# R-squared test score: 0.607
# i = 13
# R-squared test score: 0.535
# i = 14
# R-squared test score: 0.665
# i = 15
# R-squared test score: -0.329
# i = 16
# R-squared test score: 0.291
# i = 17
# R-squared test score: 0.552
# i = 18
# R-squared test score: 0.458
# i = 19
# R-squared test score: 0.596
# i = 20
# R-squared test score: 0.616
# i = 21
# R-squared test score: 0.432
# i = 22
# R-squared test score: 0.596
# i = 23
# R-squared test score: 0.531
# i = 24
# R-squared test score: 0.440
# i = 25
# R-squared test score: 0.643
# i = 26
# R-squared test score: 0.585
# i = 27
# R-squared test score: -0.191
# i = 28
# R-squared test score: 0.181
# i = 29
# R-squared test score: 0.439
# i = 30
# R-squared test score: 0.379
# i = 31
# R-squared test score: 0.591
# i = 32
# R-squared test score: 0.504
# i = 33
# R-squared test score: 0.514
# i = 34
# R-squared test score: 0.583
# i = 35
# R-squared test score: 0.519
# i = 36
# R-squared test score: 0.442
# i = 37
# R-squared test score: 0.426
# i = 38
# R-squared test score: 0.453
# i = 39
# R-squared test score: 0.588
# i = 40
# R-squared test score: 0.587
# i = 41
# R-squared test score: 0.611
# i = 42
# R-squared test score: 0.343
# i = 43
# R-squared test score: 0.660
# i = 44
# R-squared test score: 0.307
# i = 45
# R-squared test score: 0.433
# i = 46
# R-squared test score: 0.491
# i = 47
# R-squared test score: 0.512
# i = 48
# R-squared test score: 0.629
# i = 49
# R-squared test score: 0.447
# i = 50
# R-squared test score: 0.237
# i = 51
# R-squared test score: 0.335
# i = 52
# R-squared test score: 0.360
# i = 53
# R-squared test score: 0.504
# i = 54
# R-squared test score: 0.472
# i = 55
# R-squared test score: 0.462
# i = 56
# R-squared test score: 0.508
# i = 57
# R-squared test score: 0.383
# i = 58
# R-squared test score: 0.404
# i = 59
# R-squared test score: 0.408
# i = 60
# R-squared test score: 0.462
# i = 61
# R-squared test score: 0.684
# i = 62
# R-squared test score: 0.472
# i = 63
# R-squared test score: 0.462
# i = 64
# R-squared test score: 0.656
# i = 65
# R-squared test score: 0.554
# i = 66
# R-squared test score: 0.413
# i = 67
# R-squared test score: 0.618
# i = 68
# R-squared test score: 0.420
# i = 69
# R-squared test score: 0.362
# i = 70
# R-squared test score: 0.018
# i = 71
# R-squared test score: 0.487
# i = 72
# R-squared test score: 0.414
# i = 73
# R-squared test score: 0.435
# i = 74
# R-squared test score: 0.653
# i = 75
# R-squared test score: 0.471
# i = 76
# R-squared test score: 0.257
# i = 77
# R-squared test score: 0.373
# i = 78
# R-squared test score: 0.454
# i = 79
# R-squared test score: 0.277
# i = 80
# R-squared test score: 0.609
# i = 81
# R-squared test score: 0.619
# i = 82
# R-squared test score: 0.568
# i = 83
# R-squared test score: 0.158
# i = 84
# R-squared test score: 0.333
# i = 85
# R-squared test score: 0.506
# i = 86
# R-squared test score: 0.523
# i = 87
# R-squared test score: 0.352
# i = 88
# R-squared test score: 0.394
# i = 89
# R-squared test score: 0.501
# i = 90
# R-squared test score: 0.212
# i = 91
# R-squared test score: 0.538
# i = 92
# R-squared test score: 0.219
# i = 93
# R-squared test score: 0.635
# i = 94
# R-squared test score: 0.428
# i = 95
# R-squared test score: 0.451
# i = 96
# R-squared test score: 0.415
# i = 97
# R-squared test score: 0.569
# i = 98
# R-squared test score: 0.417
# i = 99
# R-squared test score: 0.551

# %%
# 7.2
# Random Forest Regression- 1

import pandas as pd
import numpy as np
import warnings; warnings.simplefilter('ignore') # Jupyter notebook warning message remove

#importing the dataset
dataset = pd.read_csv('data/rainfall_bd_2.csv')

#result of independentvariable
X = dataset.iloc[:,0:5].values # considering all station name

#result of dependent variable
y = dataset.iloc[:,36].values

#taking care of categorical variable
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()
X[:,0]= labelencoder_X.fit_transform(X[:,0])
print("\n",X,"\n")

X = np.array(X)
y = np.array(y)

from sklearn.cross_validation import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.20,random_state = 33)


from sklearn.ensemble import RandomForestRegressor

#regressor = RandomForestRegressor(random_state=0, n_estimators=200, max_depth=None, max_features=1, min_samples_leaf=1, min_samples_split=2, bootstrap=False)

for i in range(1,100):
    #regressor = RandomForestRegressor(max_depth=None, random_state=i)
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.20,random_state = i)
    regressor = RandomForestRegressor(n_estimators=200, max_depth=None, max_features=1, min_samples_leaf=1, min_samples_split=2, bootstrap=False)
    regressor.fit(X_train, y_train)

    predicted = regressor.predict(X_test)
    #print("Prediction Result: ",predicted1)
    print("i = ",i)

    print('R-squared test score: {:.3f}'.format(regressor.score(X_test,y_test))) # R-Squared test score

print("Actual=",y_test[0:6],"\n")
print("Predict=",predicted[0:6],"\n")

import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
plt.plot(y_test[0:50],label="Actual")
plt.plot(predicted[0:50],color="indianred",label="Predicted")
plt.xlabel('Number of Observation')
plt.ylabel('Rainfall (mm)')
plt.title('Rainfall Prediction with Random Forest Regression',fontsize=10)
plt.legend()
plt.show()
# Out:
#  [[0 1995 1 24.9 10.7]
#  [0 1995 2 27.7 15.0]
#  [0 1995 3 33.0 19.5]
#  ...,
#  [31 2012 10 31.6 24.3]
#  [31 2012 11 30.6 18.3]
#  [31 2012 12 27.7 16.4]]
#
# i =  1
# R-squared test score: 0.740
# i =  2
# R-squared test score: 0.785
# i =  3
# R-squared test score: 0.754
# i =  4
# R-squared test score: 0.788
# i =  5
# R-squared test score: 0.809
# i =  6
# R-squared test score: 0.744
# i =  7
# R-squared test score: 0.756
# i =  8
# R-squared test score: 0.768
# i =  9
# R-squared test score: 0.790
# i =  10
# R-squared test score: 0.798
# i =  11
# R-squared test score: 0.792
# i =  12
# R-squared test score: 0.745
# i =  13
# R-squared test score: 0.792
# i =  14
# R-squared test score: 0.754
# i =  15
# R-squared test score: 0.736
# i =  16
# R-squared test score: 0.757
# i =  17
# R-squared test score: 0.782
# i =  18
# R-squared test score: 0.782
# i =  19
# R-squared test score: 0.786
# i =  20
# R-squared test score: 0.782
# i =  21
# R-squared test score: 0.787
# i =  22
# R-squared test score: 0.747
# i =  23
# R-squared test score: 0.802
# i =  24
# R-squared test score: 0.804
# i =  25
# R-squared test score: 0.796
# i =  26
# R-squared test score: 0.775
# i =  27
# R-squared test score: 0.761
# i =  28
# R-squared test score: 0.726
# i =  29
# R-squared test score: 0.799
# i =  30
# R-squared test score: 0.762
# i =  31
# R-squared test score: 0.810
# i =  32
# R-squared test score: 0.807
# i =  33
# R-squared test score: 0.790
# i =  34
# R-squared test score: 0.795
# i =  35
# R-squared test score: 0.806
# i =  36
# R-squared test score: 0.805
# i =  37
# R-squared test score: 0.795
# i =  38
# R-squared test score: 0.801
# i =  39
# R-squared test score: 0.813
# i =  40
# R-squared test score: 0.805
# i =  41
# R-squared test score: 0.773
# i =  42
# R-squared test score: 0.808
# i =  43
# R-squared test score: 0.759
# i =  44
# R-squared test score: 0.787
# i =  45
# R-squared test score: 0.721
# i =  46
# R-squared test score: 0.796
# i =  47
# R-squared test score: 0.836
# i =  48
# R-squared test score: 0.805
# i =  49
# R-squared test score: 0.790
# i =  50
# R-squared test score: 0.811
# i =  51
# R-squared test score: 0.796
# i =  52
# R-squared test score: 0.794
# i =  53
# R-squared test score: 0.803
# i =  54
# R-squared test score: 0.795
# i =  55
# R-squared test score: 0.781
# i =  56
# R-squared test score: 0.794
# i =  57
# R-squared test score: 0.803
# i =  58
# R-squared test score: 0.802
# i =  59
# R-squared test score: 0.801
# i =  60
# R-squared test score: 0.771
# i =  61
# R-squared test score: 0.732
# i =  62
# R-squared test score: 0.743
# i =  63
# R-squared test score: 0.789
# i =  64
# R-squared test score: 0.808
# i =  65
# R-squared test score: 0.790
# i =  66
# R-squared test score: 0.798
# i =  67
# R-squared test score: 0.797
# i =  68
# R-squared test score: 0.815
# i =  69
# R-squared test score: 0.788
# i =  70
# R-squared test score: 0.759
# i =  71
# R-squared test score: 0.733
# i =  72
# R-squared test score: 0.807
# i =  73
# R-squared test score: 0.794
# i =  74
# R-squared test score: 0.772
# i =  75
# R-squared test score: 0.767
# i =  76
# R-squared test score: 0.750
# i =  77
# R-squared test score: 0.793
# i =  78
# R-squared test score: 0.811
# i =  79
# R-squared test score: 0.807
# i =  80
# R-squared test score: 0.798
# i =  81
# R-squared test score: 0.792
# i =  82
# R-squared test score: 0.774
# i =  83
# R-squared test score: 0.765
# i =  84
# R-squared test score: 0.812
# i =  85
# R-squared test score: 0.803
# i =  86
# R-squared test score: 0.789
# i =  87
# R-squared test score: 0.790
# i =  88
# R-squared test score: 0.783
# i =  89
# R-squared test score: 0.794
# i =  90
# R-squared test score: 0.791
# i =  91
# R-squared test score: 0.753
# i =  92
# R-squared test score: 0.782
# i =  93
# R-squared test score: 0.737
# i =  94
# R-squared test score: 0.783
# i =  95
# R-squared test score: 0.808
# i =  96
# R-squared test score: 0.804
# i =  97
# R-squared test score: 0.747
# i =  98
# R-squared test score: 0.806
# i =  99
# R-squared test score: 0.804
# Actual= [370 322  86  46   0  98]
#
# Predict= [ 320.46   463.41    28.24   102.775    1.095  180.88 ]

# %%
# 7.1
# Random Forest Regression- 2
# with Feature Scaling

import pandas as pd
import numpy as np
import warnings; warnings.simplefilter('ignore') # Jupyter notebook warning message remove

#importing the dataset
dataset = pd.read_csv('data/rainfall_bd_2.csv')

#result of independentvariable
X = dataset.iloc[:,0:5].values # considering all station name

#result of dependent variable
y = dataset.iloc[:,36].values

#taking careof missing data
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()
X[:,0]= labelencoder_X.fit_transform(X[:,0])
print("\n",X,"\n")

# Feature Scaling- MinMaxScaler
from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler()

X = np.array(X)
y = np.array(y)

from sklearn.cross_validation import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.20,random_state = 33)


from sklearn.ensemble import RandomForestRegressor

#regressor = RandomForestRegressor(random_state=0, n_estimators=200, max_depth=None, max_features=1, min_samples_leaf=1, min_samples_split=2, bootstrap=False)

for i in range(1,100):
    #regressor = RandomForestRegressor(max_depth=None, random_state=i)
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.20,random_state = i)
    
    # Feature Scaling- MinMaxScaler
    
    X_train_n = scaler.fit_transform(X_train)
    X_test_n = scaler.fit_transform(X_test)
    y_train_n = scaler.fit_transform(y_train)
    y_test_n = scaler.fit_transform(y_test)
    
    regressor = RandomForestRegressor(n_estimators=200, max_depth=None, max_features=1, min_samples_leaf=1, min_samples_split=2, bootstrap=False)
    regressor.fit(X_train_n, y_train_n)

    predicted = regressor.predict(X_test_n)
    #print("Prediction Result: ",predicted)
    print("i = ",i)

    print('R-squared test score: {:.3f}'.format(regressor.score(X_test_n,y_test_n))) # R-Squared test score

#Undo the scaling of X according to feature_range.    
X_train_d = scaler.inverse_transform(X_train_n)
X_test_d = scaler.inverse_transform(X_test_n)
y_train_d = scaler.inverse_transform(y_train_n)
y_test_d = scaler.inverse_transform(y_test_n)
predicted_d = scaler.inverse_transform(predicted)

import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
plt.plot(y_test_d[0:50],label="Actual")
plt.plot(predicted_d[0:50],color="indianred",label="Predicted")
plt.xlabel('Number of Observation')
plt.ylabel('Rainfall (mm)')
plt.title('Rainfall Prediction with Random Forest Regression using Feature Scaling',fontsize=10)
plt.legend()
plt.show()
# Out:
#  [[0 1995 1 24.9 10.7]
#  [0 1995 2 27.7 15.0]
#  [0 1995 3 33.0 19.5]
#  ...,
#  [31 2012 10 31.6 24.3]
#  [31 2012 11 30.6 18.3]
#  [31 2012 12 27.7 16.4]]
#
# i =  1
# R-squared test score: 0.312
# i =  2
# R-squared test score: 0.419
# i =  3
# R-squared test score: 0.603
# i =  4
# R-squared test score: 0.536
# i =  5
# R-squared test score: 0.406
# i =  6
# R-squared test score: 0.580
# i =  7
# R-squared test score: 0.616
# i =  8
# R-squared test score: 0.588
# i =  9
# R-squared test score: 0.522
# i =  10
# R-squared test score: 0.502
# i =  11
# R-squared test score: 0.554
# i =  12
# R-squared test score: 0.704
# i =  13
# R-squared test score: 0.536
# i =  14
# R-squared test score: 0.726
# i =  15
# R-squared test score: -0.054
# i =  16
# R-squared test score: 0.372
# i =  17
# R-squared test score: 0.577
# i =  18
# R-squared test score: 0.483
# i =  19
# R-squared test score: 0.603
# i =  20
# R-squared test score: 0.628
# i =  21
# R-squared test score: 0.490
# i =  22
# R-squared test score: 0.662
# i =  23
# R-squared test score: 0.569
# i =  24
# R-squared test score: 0.478
# i =  25
# R-squared test score: 0.658
# i =  26
# R-squared test score: 0.602
# i =  27
# R-squared test score: 0.212
# i =  28
# R-squared test score: 0.271
# i =  29
# R-squared test score: 0.409
# i =  30
# R-squared test score: 0.454
# i =  31
# R-squared test score: 0.597
# i =  32
# R-squared test score: 0.521
# i =  33
# R-squared test score: 0.554
# i =  34
# R-squared test score: 0.603
# i =  35
# R-squared test score: 0.563
# i =  36
# R-squared test score: 0.464
# i =  37
# R-squared test score: 0.435
# i =  38
# R-squared test score: 0.487
# i =  39
# R-squared test score: 0.622
# i =  40
# R-squared test score: 0.568
# i =  41
# R-squared test score: 0.584
# i =  42
# R-squared test score: 0.381
# i =  43
# R-squared test score: 0.710
# i =  44
# R-squared test score: 0.327
# i =  45
# R-squared test score: 0.581
# i =  46
# R-squared test score: 0.498
# i =  47
# R-squared test score: 0.552
# i =  48
# R-squared test score: 0.598
# i =  49
# R-squared test score: 0.476
# i =  50
# R-squared test score: 0.280
# i =  51
# R-squared test score: 0.357
# i =  52
# R-squared test score: 0.377
# i =  53
# R-squared test score: 0.546
# i =  54
# R-squared test score: 0.446
# i =  55
# R-squared test score: 0.480
# i =  56
# R-squared test score: 0.547
# i =  57
# R-squared test score: 0.431
# i =  58
# R-squared test score: 0.379
# i =  59
# R-squared test score: 0.440
# i =  60
# R-squared test score: 0.499
# i =  61
# R-squared test score: 0.734
# i =  62
# R-squared test score: 0.600
# i =  63
# R-squared test score: 0.490
# i =  64
# R-squared test score: 0.680
# i =  65
# R-squared test score: 0.543
# i =  66
# R-squared test score: 0.468
# i =  67
# R-squared test score: 0.610
# i =  68
# R-squared test score: 0.421
# i =  69
# R-squared test score: 0.423
# i =  70
# R-squared test score: 0.256
# i =  71
# R-squared test score: 0.630
# i =  72
# R-squared test score: 0.460
# i =  73
# R-squared test score: 0.492
# i =  74
# R-squared test score: 0.662
# i =  75
# R-squared test score: 0.474
# i =  76
# R-squared test score: 0.387
# i =  77
# R-squared test score: 0.375
# i =  78
# R-squared test score: 0.465
# i =  79
# R-squared test score: 0.319
# i =  80
# R-squared test score: 0.624
# i =  81
# R-squared test score: 0.639
# i =  82
# R-squared test score: 0.581
# i =  83
# R-squared test score: 0.319
# i =  84
# R-squared test score: 0.360
# i =  85
# R-squared test score: 0.507
# i =  86
# R-squared test score: 0.451
# i =  87
# R-squared test score: 0.358
# i =  88
# R-squared test score: 0.403
# i =  89
# R-squared test score: 0.545
# i =  90
# R-squared test score: 0.283
# i =  91
# R-squared test score: 0.670
# i =  92
# R-squared test score: 0.226
# i =  93
# R-squared test score: 0.720
# i =  94
# R-squared test score: 0.427
# i =  95
# R-squared test score: 0.456
# i =  96
# R-squared test score: 0.414
# i =  97
# R-squared test score: 0.656
# i =  98
# R-squared test score: 0.423
# i =  99
# R-squared test score: 0.531

# %%
# Report a ata lekha lagbe na

# 8.1
# Gradient Boosting Regressor

import pandas as pd
import numpy as np

#importing the dataset
dataset = pd.read_csv('data/rainfall_bd_2.csv')

#result of independentvariable
X = dataset.iloc[:,0:5].values # considering all station name

#result of dependent variable
y = dataset.iloc[:,36].values

#taking care of categorical variable
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()
X[:,0]= labelencoder_X.fit_transform(X[:,0])
print("\n",X,"\n")

# Feature Scaling- MinMaxScaler
from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y)

X = np.array(X)
y = np.array(y)

from sklearn.cross_validation import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.20,random_state = 33)


from sklearn.metrics import mean_squared_error
from sklearn.ensemble import GradientBoostingRegressor

for i in range(1,100):
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.20,random_state = i)
    est = GradientBoostingRegressor(n_estimators=150, learning_rate=0.1,max_depth=1,loss='ls')
    est.fit(X_train, y_train)

    predicted1 = est.predict(X_test)
    #print("Prediction Result: ",predicted1)
    print("i = ",i)

    print('R-squared test score: {:.3f}'.format(est.score(X_test,y_test))) # R-Squared test score

print("Actual=",y_test[0:6],"\n")
print("Predict=",predicted1[0:6],"\n")

print(mean_squared_error(y_test, est.predict(X_test)))

import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="darkgrid")
sns.tsplot(y_test[0:50])
sns.tsplot(predicted1[0:50],color="indianred")
plt.xlabel('Number of Observation')
plt.ylabel('Rainfall (mm)')
plt.title('Rainfall Prediction with Gradient Boosting Regressor')
plt.show()
# Out:
#  [[0 1995 1 24.9 10.7]
#  [0 1995 2 27.7 15.0]
#  [0 1995 3 33.0 19.5]
#  ...,
#  [31 2012 10 31.6 24.3]
#  [31 2012 11 30.6 18.3]
#  [31 2012 12 27.7 16.4]]
#
# i =  1
# R-squared test score: 0.585
# i =  2
# R-squared test score: 0.631
# i =  3
# R-squared test score: 0.613
# i =  4
# R-squared test score: 0.627
# i =  5
# R-squared test score: 0.661
# i =  6
# R-squared test score: 0.604
# i =  7
# R-squared test score: 0.598
# i =  8
# R-squared test score: 0.647
# i =  9
# R-squared test score: 0.632
# i =  10
# R-squared test score: 0.653
# i =  11
# R-squared test score: 0.651
# i =  12
# R-squared test score: 0.603
# i =  13
# R-squared test score: 0.639
# i =  14
# R-squared test score: 0.630
# i =  15
# R-squared test score: 0.601
# i =  16
# R-squared test score: 0.609
# i =  17
# R-squared test score: 0.626
# i =  18
# R-squared test score: 0.637
# i =  19
# R-squared test score: 0.634
# i =  20
# R-squared test score: 0.639
# i =  21
# R-squared test score: 0.650
# i =  22
# R-squared test score: 0.611
# i =  23
# R-squared test score: 0.672
# i =  24
# R-squared test score: 0.643
# i =  25
# R-squared test score: 0.632
# i =  26
# R-squared test score: 0.637
# i =  27
# R-squared test score: 0.600
# i =  28
# R-squared test score: 0.596
# i =  29
# R-squared test score: 0.670
# i =  30
# R-squared test score: 0.627
# i =  31
# R-squared test score: 0.638
# i =  32
# R-squared test score: 0.652
# i =  33
# R-squared test score: 0.639
# i =  34
# R-squared test score: 0.639
# i =  35
# R-squared test score: 0.647
# i =  36
# R-squared test score: 0.642
# i =  37
# R-squared test score: 0.647
# i =  38
# R-squared test score: 0.650
# i =  39
# R-squared test score: 0.655
# i =  40
# R-squared test score: 0.650
# i =  41
# R-squared test score: 0.657
# i =  42
# R-squared test score: 0.654
# i =  43
# R-squared test score: 0.595
# i =  44
# R-squared test score: 0.668
# i =  45
# R-squared test score: 0.578
# i =  46
# R-squared test score: 0.646
# i =  47
# R-squared test score: 0.657
# i =  48
# R-squared test score: 0.650
# i =  49
# R-squared test score: 0.648
# i =  50
# R-squared test score: 0.662
# i =  51
# R-squared test score: 0.626
# i =  52
# R-squared test score: 0.634
# i =  53
# R-squared test score: 0.660
# i =  54
# R-squared test score: 0.671
# i =  55
# R-squared test score: 0.622
# i =  56
# R-squared test score: 0.634
# i =  57
# R-squared test score: 0.662
# i =  58
# R-squared test score: 0.656
# i =  59
# R-squared test score: 0.653
# i =  60
# R-squared test score: 0.637
# i =  61
# R-squared test score: 0.578
# i =  62
# R-squared test score: 0.598
# i =  63
# R-squared test score: 0.650
# i =  64
# R-squared test score: 0.638
# i =  65
# R-squared test score: 0.650
# i =  66
# R-squared test score: 0.654
# i =  67
# R-squared test score: 0.643
# i =  68
# R-squared test score: 0.665
# i =  69
# R-squared test score: 0.631
# i =  70
# R-squared test score: 0.606
# i =  71
# R-squared test score: 0.598
# i =  72
# R-squared test score: 0.652
# i =  73
# R-squared test score: 0.630
# i =  74
# R-squared test score: 0.608
# i =  75
# R-squared test score: 0.617
# i =  76
# R-squared test score: 0.608
# i =  77
# R-squared test score: 0.654
# i =  78
# R-squared test score: 0.659
# i =  79
# R-squared test score: 0.647
# i =  80
# R-squared test score: 0.639
# i =  81
# R-squared test score: 0.642
# i =  82
# R-squared test score: 0.642
# i =  83
# R-squared test score: 0.605
# i =  84
# R-squared test score: 0.640
# i =  85
# R-squared test score: 0.655
# i =  86
# R-squared test score: 0.642
# i =  87
# R-squared test score: 0.653
# i =  88
# R-squared test score: 0.639
# i =  89
# R-squared test score: 0.648
# i =  90
# R-squared test score: 0.624
# i =  91
# R-squared test score: 0.621
# i =  92
# R-squared test score: 0.643
# i =  93
# R-squared test score: 0.604
# i =  94
# R-squared test score: 0.658
# i =  95
# R-squared test score: 0.633
# i =  96
# R-squared test score: 0.670
# i =  97
# R-squared test score: 0.591
# i =  98
# R-squared test score: 0.647
# i =  99
# R-squared test score: 0.657
# Actual= [ 0.12329224  0.10729757  0.02865711  0.01532822  0.          0.03265578]
#
# Predict= [ 0.11799473  0.17228396  0.0047728   0.01854609  0.01142996  0.05044099]
#
# 0.00230732323613
